# %%
import pandas as pd
import sklearn as sk
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import plot_confusion_matrix

# %%
# LEE ARCHIVO CON LAS CARACTERISTICAS DE LOS AUDIOS
###################################################
Features = 'C:\\Data\\2_Preprocesamiento\\Pruebas_8\\Todos.csv'
dataframe = pd.read_csv(Features,sep=',')
# dataframe = dataframe.drop(dataframe.columns[[9]], axis='columns')
# dataframe.head(2)

# %%
# NORMALIZA LOS DATOS DE ENTRENAMIENTO Y DE TEST
####################################################
scaler = MinMaxScaler()
dataframe[['chroma_stft','chroma_cqt','chroma_cens', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff', 'mfcc', 'melspectrogram', 'feature.tonnetz', 'onset_detect', 'rmse', 'zero_crossing_rate', 'spectral_flatness', 'pitch', 'freqmin','freqmax', 'duration']] = scaler.fit_transform(dataframe[['chroma_stft','chroma_cqt','chroma_cens', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff', 'mfcc', 'melspectrogram', 'feature.tonnetz', 'onset_detect', 'rmse', 'zero_crossing_rate', 'spectral_flatness', 'pitch', 'freqmin','freqmax', 'duration']])
# dataframe.head(10)

# %%
# SELECCION DE LAS CARARTERISTICAS A ANALIZAR <17>
###################################################
X=dataframe[['chroma_stft','chroma_cqt','chroma_cens', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff', 'mfcc', 'melspectrogram', 'feature.tonnetz','onset_detect', 'rmse', 'zero_crossing_rate', 'spectral_flatness', 'pitch', 'freqmin','freqmax', 'duration']]  # Features
y=dataframe['especie']  # Labels

# %%
# SELECCIONA LOS DATOS DE ENTRENAMIENTO 80% Y DE TEST 20%
###################################################
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
# COMBINACION DE CARACTERISTICAS
###################################################
# EJERCICIO 2
# X_train = X_train.drop(columns=['pitch'])
# X_test = X_test.drop(columns=['pitch'])
# EJERCICIO 3
# X_train = X_train.drop(columns=['feature.tonnetz'])
# X_test = X_test.drop(columns=['feature.tonnetz'])
# EJERCICIO 4
# X_train = X_train.drop(columns=['spectral_flatness'])
# X_test = X_test.drop(columns=['spectral_flatness'])
# EJERCICIO 5
# X_train = X_train.drop(columns=['chroma_cqt','chroma_cens'])
# X_test = X_test.drop(columns=['chroma_cqt','chroma_cens'])
# EJERCICIO 6
# X_train = X_train.drop(columns=['spectral_rolloff','rmse'])
# X_test = X_test.drop(columns=['spectral_rolloff','rmse'])
# EJERCICIO 7
# X_train = X_train.drop(columns=['spectral_bandwidth','melspectrogram'])
# X_test = X_test.drop(columns=['spectral_bandwidth','melspectrogram'])
# EJERCICIO 8
# X_train = X_train.drop(columns=['spectral_centroid','mfcc'])
# X_test = X_test.drop(columns=['spectral_centroid','mfcc'])
#################
# X_train

# %%
# APLICA ALGORITMO DE BOSQUES ALEATORIOS
####################################################
RF = RandomForestClassifier(n_estimators=500, max_depth=20, random_state=0).fit(X_train, y_train)
RF.predict(X_test)
round(RF.score(X_test, y_test), 4)
# Out:
# 0.9013

# %%
# APLICA ALGORITMO DE VECINOS MAS CERCANOS
####################################################
n_neighbors = 1
KNN = KNeighborsClassifier(n_neighbors).fit(X_train, y_train)
KNN.predict(X_test)
round(KNN.score(X_test, y_test), 4)
# Out:
# 0.8013

# %%
# APLICA ALGORITMO DE REDES NERONALES
####################################################
NN = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(150, 10), random_state=1).fit(X_train, y_train)
NN.predict(X_test)
round(NN.score(X_test, y_test), 4)
# Out:
# C:\Users\ravargas\AppData\Local\conda\conda\envs\Ambiente\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.7253

# %%
# APLICA ALGORITMO DE ARBOLES DE DECISION
####################################################
TREE = DecisionTreeClassifier().fit(X_train, y_train)
TREE.predict(X_test)
round(TREE.score(X_test, y_test), 4)
# Out:
# 0.7658

# %%
# APLICA ALGORITMO DE NAIVE BAYES
####################################################
GNB = GaussianNB().fit(X_train, y_train)
GNB.predict(X_test)
round(GNB.score(X_test, y_test), 4)
# Out:
# 0.6899

# %%
# APLICA ALGORITMO DE MAQUINA DE SOPORTE VECTORIAL
####################################################
SVM = svm.SVC(decision_function_shape="ovo", gamma='auto').fit(X_train, y_train)
SVM.predict(X_test)
round(SVM.score(X_test, y_test), 4)
# Out:
# 0.6013

# %%
#features_name =['chroma_stft', 'chroma_cqt','chroma_cens', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff', 'mfcc', 'melspectrogram', 'feature.tonnetz','onset_detect', 'rmse', 'zero_crossing_rate', 'spectral_flatness', 'pitch', 'freqmin','freqmax', 'duration']
#feature_imp = pd.Series(RF.feature_importances_,index=features_name).sort_values(ascending=False)
#%matplotlib inline
#sns.barplot(x=feature_imp, y=feature_imp.index)
## Add labels to your graph
#plt.xlabel('Ranking de caracteristicas')
#plt.ylabel('caracteristicas')
#plt.title("Valor de las caracteristicas")
#plt.legend()
#plt.show()

# %%
X_train
# Out:
#       chroma_stft  onset_detect  zero_crossing_rate   freqmin   freqmax  \
# 1812     0.347517      0.061122            0.443540  0.351081  0.198473
# 2889     0.304574      0.022362            0.352491  0.511250  0.549618
# 94       0.444685      0.016995            0.265590  0.000000  0.435114
# 2628     0.233707      0.518595            0.442953  0.280927  0.175573
# 2892     0.311205      0.033543            0.300829  0.403696  0.503817
# 1163     0.625819      0.101075            0.377192  0.228312  0.687023
# 2006     0.116196      0.196880            0.276366  0.263389  0.312977
# 1355     0.344036      0.267977            0.361055  0.614156  0.335878
# 691      0.261881      0.205231            0.384805  0.386157  0.893130
# 246      0.144006      0.157857            0.444962  0.438772  0.427481
# 3469     0.277185      0.026834            0.326414  0.000000  0.053435
# 2391     0.606883      0.033915            0.252536  0.298466  0.435114
# ...
